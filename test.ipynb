# %% [markdown]
# <a href="https://colab.research.google.com/github/vipinneemamnit/coding_practice/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
2+2
# Out:
# 4

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -----------------------
# absl-py                      1.4.0
# accelerate                   0.34.2
# altair                       4.2.2
# annotated-types              0.7.0
# anyio                        3.7.1
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# array_record                 0.5.1
# astunparse                   1.6.3
# attrs                        24.2.0
# audioread                    3.0.1
# backcall                     0.2.0
# beautifulsoup4               4.12.3
# bleach                       6.1.0
# blinker                      1.4
# blis                         0.7.11
# build                        1.2.2
# cachetools                   5.5.0
# catalogue                    2.0.10
# certifi                      2024.8.30
# cffi                         1.17.1
# charset-normalizer           3.3.2
# chex                         0.1.87
# click                        8.1.7
# ...
